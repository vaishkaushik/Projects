# %%
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("Best Shows Netflix.csv")

# %%
df.head()
# Out:
#    index                       TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 0      0                Breaking Bad          2008    9.5          1727694
# 1      1  Avatar: The Last Airbender          2005    9.3           297336
# 2      2                  Our Planet          2019    9.3            41386
# 3      3                Kota Factory          2019    9.3            66985
# 4      4              The Last Dance          2020    9.1           108321
#
#    DURATION  NUMBER_OF_SEASONS   MAIN_GENRE MAIN_PRODUCTION
# 0        48                  5        drama              US
# 1        24                  3        scifi              US
# 2        50                  1  documentary              GB
# 3        42                  2        drama              IN
# 4        50                  1  documentary              US

# %%
df.shape
# Out:
# (246, 9)

# %%
# Loading the API token to OpenAI environment
llm = OpenAI(api_token='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')
# Initializing an instance of PandasAI with OpenAI environment
pandas_ai = PandasAI(llm)

# %%
prompt="What is the shape of dataset?"
pandas_ai(df,prompt=prompt)
# Out:
# '246 9'

# %%
prompt="What are different number of seasons in this dataset?"
pandas_ai(df,prompt=prompt)
# Out:
# array([ 5,  3,  1,  2,  4,  9,  6, 21, 12, 11, 15, 10,  7,  8, 19, 18],
#       dtype=int64)

# %%
df.NUMBER_OF_SEASONS.unique()
# Out:
# array([ 5,  3,  1,  2,  4,  9,  6, 21, 12, 11, 15, 10,  7,  8, 19, 18],
#       dtype=int64)

# %%
prompt="Plot a countplot for Main Genres"
pandas_ai.run(df,prompt=prompt)

# %%
prompt="Plot a countplot for Main Genres with xticks rotated to 90 degrees"
pandas_ai.run(df,prompt=prompt)

# %%
prompt="Plot a countplot for Main Genres with xticks rotated to 90 degrees with counts sorted in descending order"
pandas_ai.run(df,prompt=prompt)

# %%
prompt="Drop column index in place"
pandas_ai.run(df,prompt=prompt)
# Out:
# ''

# %%
df.head()
# Out:
#                         TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  DURATION  \
# 0                Breaking Bad          2008    9.5          1727694        48
# 1  Avatar: The Last Airbender          2005    9.3           297336        24
# 2                  Our Planet          2019    9.3            41386        50
# 3                Kota Factory          2019    9.3            66985        42
# 4              The Last Dance          2020    9.1           108321        50
#
#    NUMBER_OF_SEASONS   MAIN_GENRE MAIN_PRODUCTION
# 0                  5        drama              US
# 1                  3        scifi              US
# 2                  1  documentary              GB
# 3                  2        drama              IN
# 4                  1  documentary              US

# %%
prompt="Which production has highest average score"
pandas_ai.run(df,prompt=prompt)
# Out:
# 'IN'

# %%
df.groupby('MAIN_PRODUCTION')['SCORE'].mean().sort_values(ascending=False)[:1]
# Out:
# MAIN_PRODUCTION
# IN    8.8
# Name: SCORE, dtype: float64

# %%
prompt="Plot countplot for every categorical variable excluding column TITLE"
pandas_ai.run(df,prompt=prompt)
# Out:
# Rate limit reached for default-gpt-3.5-turbo in organization org-mnfzq7YsnGukbI644iBBmE5t on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nRate limit reached for default-gpt-3.5-turbo in organization org-mnfzq7YsnGukbI644iBBmE5t on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.\n'

# %%
prompt="Are there any missing values"
pandas_ai.run(df,prompt=prompt)
# Out:
# Rate limit reached for default-gpt-3.5-turbo in organization org-mnfzq7YsnGukbI644iBBmE5t on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nRate limit reached for default-gpt-3.5-turbo in organization org-mnfzq7YsnGukbI644iBBmE5t on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.\n'
